# %% [markdown]
# ### Importing and Understanding Data

# %%
import pandas as pd
import numpy as np

# %%
# Importing Housing.csv
housing = pd.read_csv('newhousing.csv')

# %%
# Looking at the first five rows
housing.head()
# Out:
#      price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  5250000  5500         3          2        1         1          0         1
# 1  4480000  4040         3          1        2         1          0         0
# 2  3570000  3640         2          1        1         1          0         0
# 3  2870000  3040         2          1        1         0          0         0
# 4  3570000  4500         2          1        1         0          0         0
#
#    hotwaterheating  airconditioning  parking  prefarea  semi-furnished  \
# 0                0                0        0         0               1
# 1                0                0        1         0               1
# 2                0                0        0         0               0
# 3                0                0        0         0               0
# 4                0                0        0         0               0
#
#    unfurnished  areaperbedroom   bbratio
# 0            0     1833.333333  0.666667
# 1            0     1346.666667  0.333333
# 2            1     1820.000000  0.500000
# 3            1     1520.000000  0.500000
# 4            0     2250.000000  0.500000

# %%
housing.shape
# Out:
# (545, 16)

# %%
# What type of values are stored in the columns?
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            545 non-null    int64
#  1   area             545 non-null    int64
#  2   bedrooms         545 non-null    int64
#  3   bathrooms        545 non-null    int64
#  4   stories          545 non-null    int64
#  5   mainroad         545 non-null    int64
#  6   guestroom        545 non-null    int64
#  7   basement         545 non-null    int64
#  8   hotwaterheating  545 non-null    int64
#  9   airconditioning  545 non-null    int64
#  10  parking          545 non-null    int64
#  11  prefarea         545 non-null    int64
#  12  semi-furnished   545 non-null    int64
#  13  unfurnished      545 non-null    int64
#  14  areaperbedroom   545 non-null    float64
#  15  bbratio          545 non-null    float64
# dtypes: float64(2), int64(14)
# memory usage: 68.2 KB

# %% [markdown]
# ## Splitting Data into Training and Testing Sets

# %%
housing.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'semi-furnished', 'unfurnished',
#        'areaperbedroom', 'bbratio'],
#       dtype='object')

# %%
# Putting feature variable to X
X = housing[['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'semi-furnished', 'unfurnished',
       'areaperbedroom', 'bbratio']]

# Putting response variable to y
y = housing['price']

# %%
# Importing matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Let's see the correlation matrix 
plt.figure(figsize = (16,10))     # Size of the figure
sns.heatmap(X.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
#creating correlation matrix for the given data
corrmat = np.corrcoef(X.transpose())
ij_max = np.unravel_index(corrmat_diag_zero.argmax(), corrmat_diag_zero.shape)
print("ij_max",ij_max)
# Out:
# <AxesSubplot:>

# %%
#Make a diagonal matrix with diagonal entry of Matrix corrmat
p=np.diagflat(corrmat.diagonal())

# %%
# subtract diagonal entries making all diagonals 0
corrmat_diag_zero = corrmat - p
print("max corr:",corrmat_diag_zero.max(), ", min corr: ", corrmat_diag_zero.min(),)
# Out:
# max corr: 0.8056104195904634 , min corr:  -0.5884049771343843

# %% [markdown]
# ### Question No. 1 and 2

# %%
# Retrieve the (i,j) index for which matrix has maximum value

ij_max = np.unravel_index(
#                 ## add code to solve for Question 1 and Question 2
)
print("ij_max is",ij_max)
print("Maximum correlation :",corrmat_diag_zero[ij_max])

# %%
import matplotlib.pyplot as plt
from sklearn import  linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import explained_variance_score
#Importing the PCA module
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=6,random_state=100)

# %%
pp = pca.fit_transform(X)

# %%
pca.components_
# Out:
# array([[ 9.50454807e-01,  2.98115950e-05,  3.73872195e-05,
#          2.11596585e-05,  4.44083760e-05,  2.23944942e-05,
#          8.59156321e-06, -9.95869397e-07,  4.33840044e-05,
#          1.30598999e-04,  4.26148210e-05,  4.90372096e-07,
#         -2.80161511e-05,  3.10862725e-01,  5.42652413e-06],
#        [-3.10862188e-01, -1.37975638e-03, -3.86482880e-04,
#         -7.71177646e-04,  6.78456841e-06, -8.76254086e-05,
#         -9.70391400e-05, -1.02962578e-05, -1.51011381e-04,
#         -2.27321576e-04, -8.60343299e-05, -5.98623229e-05,
#          9.68612037e-05,  9.50453539e-01,  1.00344156e-04],
#        [-1.71023435e-04,  3.30535147e-02,  1.07556685e-01,
#          8.59639706e-01,  2.37427731e-02, -1.60063754e-02,
#         -1.83038523e-01, -8.46802735e-03,  1.39672244e-01,
#         -4.34511771e-01, -1.89315673e-02, -5.70313751e-02,
#          3.24204560e-02,  6.19184229e-04,  3.15051415e-02],
#        [ 3.24519444e-04, -1.56882861e-02, -1.45190513e-01,
#         -3.97546668e-01, -8.03322921e-02,  8.34491502e-03,
#          4.61983033e-02, -1.94959402e-02, -1.38123407e-01,
#         -8.78306147e-01, -2.40339846e-04, -5.57582351e-02,
#          1.26403615e-01, -5.36084603e-04, -4.47870715e-02],
#        [ 7.37613621e-05, -2.60343587e-02, -1.05540616e-01,
#         -2.32364410e-02, -4.04448910e-02, -1.18728674e-01,
#         -2.21491224e-01, -2.00197880e-02, -8.54341036e-03,
#          1.58819652e-01, -7.36817867e-02, -6.94425348e-01,
#          6.39161424e-01, -1.84549972e-04, -3.11834882e-02],
#        [-1.22824807e-04, -7.05701322e-03,  3.18859079e-01,
#          1.41202899e-02,  6.88084255e-02,  4.00680719e-01,
#          6.52473552e-01, -2.73696499e-02,  2.95560306e-01,
#         -4.53754732e-02,  3.34925622e-01, -2.87288791e-01,
#          1.03828806e-01,  2.19931176e-04,  1.06882639e-01]])

# %%
#random_state is the seed used by the random number generator, it can be any integer.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7 ,test_size = 0.3, random_state=100)

from sklearn import preprocessing
X_scaler = preprocessing.StandardScaler().fit(X_train)
y_scaler = preprocessing.StandardScaler().fit(y_train.values.reshape(-1,1))
Xtrain=X_scaler.transform(X_train) 
ytrain=y_scaler.transform(y_train.values.reshape(-1,1)) 

Xtest=X_scaler.transform(X_test) 
ytest=y_scaler.transform(y_test.values.reshape(-1,1))

# %% [markdown]
# ### Question No. 4

# %%
pca = PCA(n_components=6,random_state=100)

#Scale and transform data to get Principal Components

## add code for question no. 4
# fit_transform and transform to get the reduced data
# Xtrain_reduced = 
# Xtest_reduced = 


regrpca = linear_model.LinearRegression()
# Train the model using the principal components of the transformed training sets
regrpca.fit(Xtrain_reduced, ytrain)
# Make predictions using the principal components of the transformed testing set
y_pred = regrpca.predict(Xtest_reduced)
print("Mean squared error: %.2f" % mean_squared_error(ytest, y_pred))
# Explained variance score: 1 is perfect prediction
print('R2 score: %.2f' % r2_score(ytest, y_pred))
